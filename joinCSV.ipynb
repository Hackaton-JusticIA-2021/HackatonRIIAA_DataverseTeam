# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import files 
import glob
from google.colab import drive

# %%
import pandas as pd

# %%
path="/content/drive/MyDrive/"

# %%
firmas=pd.read_csv(path+"Firmas.csv")
rostros=pd.read_csv(path+"rostros.csv")
sellos=pd.read_csv(path+"sellos.csv")
tablas=pd.read_csv(path+"tables.csv")

# %%
display(firmas)
# Out:
#                                                filename  width  ...  xmax  ymax
# 0     AGN_DFS_AdeR_Declaracion_de_Alfredo_Tecla_Parr...   1064  ...   166  1586
# 1     AGN_DFS_AdeR_Declaracion_de_Alfredo_Tecla_Parr...   1064  ...   119  1586
# 2     AGN_DFS_AdeR_Declaracion_de_Alfredo_Tecla_Parr...   1064  ...   661  1574
# 3     AGN_DFS_AdeR_Declaracion_de_Alfredo_Tecla_Parr...   1064  ...    51  1577
# 4     AGN_DFS_AdeR_Declaracion_de_Alfredo_Tecla_Parr...   1064  ...    35  1572
# ...                                                 ...    ...  ...   ...   ...
# 1829  AGN_DFS_C.48_De_los_Rios_Merino_Alicia_pg-096.jpg   2592  ...  2592  1730
# 1830  AGN_DFS_C.48_De_los_Rios_Merino_Alicia_pg-096.jpg   2592  ...  2561  1706
# 1831  AGN_DFS_C.48_De_los_Rios_Merino_Alicia_pg-096.jpg   2592  ...  2592  1190
# 1832  AGN_DFS_C.48_De_los_Rios_Merino_Alicia_pg-096.jpg   2592  ...   809   127
# 1833                                           roi0.png    691  ...   691   518
#
# ...

# %%
display(rostros)
# Out:
#                                              filename  ...         ymax
# 0   AGN_DFS_C.18_2_de_2_Cabrera_Arenas_Emma_pg-312...  ...  2157.521973
# 1   AGN_DFS_C.18_2_de_2_Cabrera_Arenas_Emma_pg-319...  ...   973.280945
# 2   AGN_DFS_C.18_2_de_2_Cabrera_Arenas_Emma_pg-318...  ...  1128.502075
# 3   AGN_DFS_C.240_Sanchez_Fuerte_Maria_Marcela_pg-...  ...  1204.868042
# 4   AGN_DFS_C.48_De_los_Rios_Merino_Alicia_pg-082.jpg  ...  1171.314941
# 5   AGN_DFS_C.48_De_los_Rios_Merino_Alicia_pg-060.jpg  ...   971.068176
# 6   AGN_DFS_C.48_De_los_Rios_Merino_Alicia_pg-063.jpg  ...  1309.637207
# 7   AGN_DFS_C.48_De_los_Rios_Merino_Alicia_pg-061.jpg  ...  1310.092285
# 8   AGN_DFS_C.48_De_los_Rios_Merino_Alicia_pg-049.jpg  ...  1673.347046
# 9   AGN_DFS_C.48_De_los_Rios_Merino_Alicia_pg-062.jpg  ...  1389.239136
# 10  AGN_DFS_C.48_De_los_Rios_Merino_Alicia_pg-081.jpg  ...  1353.973511
# 11  AGN_DFS_C.160_Murillo_de_Ramirez_Juventina_Mar...  ...  1127.035400
# ...

# %%
firmas.rename(columns={"etiqueta":"class"},inplace=True)

# %%
lista=[rostros,firmas,sellos,tablas]

# %%
join=pd.concat(lista,axis = 0)

# %%
join=join.iloc[:,:-1]

# %%
display(join)
# Out:
#                                              filename  ...         ymax
# 0   AGN_DFS_C.18_2_de_2_Cabrera_Arenas_Emma_pg-312...  ...  2157.521973
# 1   AGN_DFS_C.18_2_de_2_Cabrera_Arenas_Emma_pg-319...  ...   973.280945
# 2   AGN_DFS_C.18_2_de_2_Cabrera_Arenas_Emma_pg-318...  ...  1128.502075
# 3   AGN_DFS_C.240_Sanchez_Fuerte_Maria_Marcela_pg-...  ...  1204.868042
# 4   AGN_DFS_C.48_De_los_Rios_Merino_Alicia_pg-082.jpg  ...  1171.314941
# ..                                                ...  ...          ...
# 14  AGN_DFS_C.18_1_de_2_Cabrera_Arenas_Emma_pg-001...  ...  1393.495239
# 15  AGN_DFS_C.18_1_de_2_Cabrera_Arenas_Emma_pg-002...  ...  1363.855713
# 16  AGN_DFS_C.18_1_de_2_Cabrera_Arenas_Emma_pg-002...  ...  1378.372070
# 17  AGN_DFS_C.18_1_de_2_Cabrera_Arenas_Emma_pg-003...  ...  1350.099365
# 18  AGN_DFS_C.18_1_de_2_Cabrera_Arenas_Emma_pg-329...  ...  1013.575806
#
# [2760 rows x 8 columns]

# %%
join['class'] = join['class'].map({'sello':'Stamp',
                             'face':'Photo',
                             'Table':'Table',
                             'Signature':'Signature'}
                                )

# %%
display(join)
# Out:
#                                              filename  ...         ymax
# 0   AGN_DFS_C.18_2_de_2_Cabrera_Arenas_Emma_pg-312...  ...  2157.521973
# 1   AGN_DFS_C.18_2_de_2_Cabrera_Arenas_Emma_pg-319...  ...   973.280945
# 2   AGN_DFS_C.18_2_de_2_Cabrera_Arenas_Emma_pg-318...  ...  1128.502075
# 3   AGN_DFS_C.240_Sanchez_Fuerte_Maria_Marcela_pg-...  ...  1204.868042
# 4   AGN_DFS_C.48_De_los_Rios_Merino_Alicia_pg-082.jpg  ...  1171.314941
# ..                                                ...  ...          ...
# 14  AGN_DFS_C.18_1_de_2_Cabrera_Arenas_Emma_pg-001...  ...  1393.495239
# 15  AGN_DFS_C.18_1_de_2_Cabrera_Arenas_Emma_pg-002...  ...  1363.855713
# 16  AGN_DFS_C.18_1_de_2_Cabrera_Arenas_Emma_pg-002...  ...  1378.372070
# 17  AGN_DFS_C.18_1_de_2_Cabrera_Arenas_Emma_pg-003...  ...  1350.099365
# 18  AGN_DFS_C.18_1_de_2_Cabrera_Arenas_Emma_pg-329...  ...  1013.575806
#
# [2760 rows x 8 columns]

# %%
join.to_csv(path+"Reto1.csv",index=False)
